# %% [markdown]
# # Exploratory Data Analysis of Movies

# %% [markdown]
# ## Features

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('movies_complete.csv')
df.set_index('id',inplace=True)
df
# Out:
#                               title  \
# id
# 862                       Toy Story
# 8844                        Jumanji
# 15602              Grumpier Old Men
# 31357             Waiting to Exhale
# 11862   Father of the Bride Part II
# ...                             ...
# 439050                       Subdue
# 111109          Century of Birthing
# 67758                      Betrayal
# 227506             Satan Triumphant
# 461257                     Queerama
#
#                                                   tagline release_date  \
# id
# 862                                                   NaN   1995-10-30
# 8844            Roll the dice and unleash the excitement!   1995-12-15
# 15602   Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 31357   Friends are the people who let you be yourself...   1995-12-22
# 11862   Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                   ...          ...
# 439050         Rising and falling between a man and woman          NaN
# 111109                                                NaN   2011-11-17
# 67758                              A deadly game of wits.   2003-08-01
# 227506                                                NaN   1917-10-21
# 461257                                                NaN   2017-06-09
#
#                           genres           belongs_to_collection  \
# id
# 862      Animation|Comedy|Family            Toy Story Collection
# 8844    Adventure|Fantasy|Family                             NaN
# 15602             Romance|Comedy       Grumpy Old Men Collection
# 31357       Comedy|Drama|Romance                             NaN
# 11862                     Comedy  Father of the Bride Collection
# ...                          ...                             ...
# 439050              Drama|Family                             NaN
# 111109                     Drama                             NaN
# 67758      Action|Drama|Thriller                             NaN
# 227506                       NaN                             NaN
# 461257                       NaN                             NaN
#
#        original_language  budget_musd  revenue_musd  \
# id
# 862                   en         30.0    373.554033
# 8844                  en         65.0    262.797249
# 15602                 en          NaN           NaN
# 31357                 en         16.0     81.452156
# 11862                 en          NaN     76.578911
# ...                  ...          ...           ...
# 439050                fa          NaN           NaN
# 111109                tl          NaN           NaN
# 67758                 en          NaN           NaN
# 227506                en          NaN           NaN
# 461257                en          NaN           NaN
#
#                                      production_companies  \
# id
# 862                               Pixar Animation Studios
# 8844    TriStar Pictures|Teitler Film|Interscope Commu...
# 15602                         Warner Bros.|Lancaster Gate
# 31357              Twentieth Century Fox Film Corporation
# 11862           Sandollar Productions|Touchstone Pictures
# ...                                                   ...
# 439050                                                NaN
# 111109                                        Sine Olivia
# 67758                             American World Pictures
# 227506                                          Yermoliev
# 461257                                                NaN
#
#             production_countries  ...  vote_average  popularity  runtime  \
# id                                ...
# 862     United States of America  ...           7.7   21.946943     81.0
# 8844    United States of America  ...           6.9   17.015539    104.0
# 15602   United States of America  ...           6.5   11.712900    101.0
# 31357   United States of America  ...           6.1    3.859495    127.0
# 11862   United States of America  ...           5.7    8.387519    106.0
# ...                          ...  ...           ...         ...      ...
# 439050                      Iran  ...           4.0    0.072051     90.0
# 111109               Philippines  ...           9.0    0.178241    360.0
# 67758   United States of America  ...           3.8    0.903007     90.0
# 227506                    Russia  ...           NaN    0.003503     87.0
# 461257            United Kingdom  ...           NaN    0.163015     75.0
#
#                                                  overview  spoken_languages  \
# id
# 862     Led by Woody, Andy's toys live happily in his ...           English
# 8844    When siblings Judy and Peter discover an encha...  English|Français
# 15602   A family wedding reignites the ancient feud be...           English
# 31357   Cheated on, mistreated and stepped on, the wom...           English
# 11862   Just when George Banks has recovered from his ...           English
# ...                                                   ...               ...
# 439050        Rising and falling between a man and woman.             فارسی
# 111109  An artist struggles to finish his work while a...               NaN
# 67758   When one of her hits goes wrong, a professiona...           English
# 227506  In a small town live two brothers, one a minis...               NaN
# 461257  50 years after decriminalisation of homosexual...           English
#
#                                               poster_path  \
# id
# 862     <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 8844    <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 15602   <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 31357   <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 11862   <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                   ...
# 439050  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 111109  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 67758   <img src='http://image.tmdb.org/t/p/w185//eGga...
# 227506  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 461257  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                                      cast cast_size  \
# id
# 862     Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...        13
# 8844    Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...        26
# 15602   Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...         7
# 31357   Whitney Houston|Angela Bassett|Loretta Devine|...        10
# 11862   Steve Martin|Diane Keaton|Martin Short|Kimberl...        12
# ...                                                   ...       ...
# 439050            Leila Hatami|Kourosh Tahami|Elham Korda         3
# 111109  Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...        11
# 67758   Erika Eleniak|Adam Baldwin|Julie du Page|James...        15
# 227506  Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...         5
# 461257                                                NaN         0
#
#         crew_size          director
# id
# 862           106     John Lasseter
# 8844           16      Joe Johnston
# 15602           4     Howard Deutch
# 31357          10   Forest Whitaker
# 11862           7     Charles Shyer
# ...           ...               ...
# 439050          9  Hamid Nematollah
# 111109          6          Lav Diaz
# 67758           5    Mark L. Lester
# 227506          2  Yakov Protazanov
# 461257          1     Daisy Asquith
#
# [44691 rows x 21 columns]

# %%
df.isna().sum()
# Out:
# title                        0
# tagline                  24407
# release_date                34
# genres                    2105
# belongs_to_collection    40228
# original_language           10
# budget_musd              35837
# revenue_musd             37306
# production_companies     11335
# production_countries      5856
# vote_count                   0
# vote_average              2614
# popularity                   0
# runtime                   1512
# overview                   951
# spoken_languages          3597
# poster_path                224
# cast                      2189
# cast_size                    0
# crew_size                    0
# director                   731
# dtype: int64

# %%
df.release_date = pd.to_datetime(df.release_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44691 entries, 862 to 461257
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  44691 non-null  object
#  1   tagline                20284 non-null  object
#  2   release_date           44657 non-null  datetime64[ns]
#  3   genres                 42586 non-null  object
#  4   belongs_to_collection  4463 non-null   object
#  5   original_language      44681 non-null  object
#  6   budget_musd            8854 non-null   float64
#  7   revenue_musd           7385 non-null   float64
#  8   production_companies   33356 non-null  object
#  9   production_countries   38835 non-null  object
#  10  vote_count             44691 non-null  float64
#  11  vote_average           42077 non-null  float64
#  12  popularity             44691 non-null  float64
#  13  runtime                43179 non-null  float64
#  14  overview               43740 non-null  object
#  15  spoken_languages       41094 non-null  object
#  16  poster_path            44467 non-null  object
#  17  cast                   42502 non-null  object
#  18  cast_size              44691 non-null  int64
#  19  crew_size              44691 non-null  int64
#  20  director               43960 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(2), object(12)
# memory usage: 7.5+ MB

# %%
df.hist(figsize=(20,12),bins=100);

# %%
df[df['title']=='Cinderella']
# Out:
#              title                             tagline release_date  \
# id
# 11224   Cinderella  The greatest love story ever told.   1950-03-04
# 42884   Cinderella                                 NaN   1997-11-02
# 92349   Cinderella                                 NaN   1914-12-28
# 105875  Cinderella          The version children love!   2002-08-06
# 261985  Cinderella                                 NaN   2011-10-30
# 150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 42651   Cinderella                                 NaN   1947-11-28
# 44459   Cinderella                                 NaN   1957-03-31
# 289673  Cinderella                                 NaN   2000-01-01
# 114108  Cinderella                                 NaN   1899-10-01
# 98604   Cinderella                                 NaN   2012-02-14
#
#                                        genres  belongs_to_collection  \
# id
# 11224        Family|Fantasy|Animation|Romance  Cinderella Collection
# 42884   TV Movie|Family|Fantasy|Music|Romance                    NaN
# 92349                           Fantasy|Drama                    NaN
# 105875               Animation|Family|Fantasy                    NaN
# 261985                        Family|TV Movie                    NaN
# 150689           Romance|Fantasy|Family|Drama                    NaN
# 42651                   Comedy|Family|Fantasy                    NaN
# 44459                           Drama|Romance                    NaN
# 289673                                    NaN                    NaN
# 114108  Fantasy|Horror|Science Fiction|Family                    NaN
# 98604                          Comedy|Romance                    NaN
#
#        original_language  budget_musd  revenue_musd  \
# id
# 11224                 en          2.9    263.591415
# 42884                 en          NaN           NaN
# 92349                 en          NaN           NaN
# 105875                en          NaN           NaN
# 261985                en          NaN           NaN
# 150689                en         95.0    543.514353
# 42651                 ru          NaN           NaN
# 44459                 en          NaN           NaN
# 289673                en          NaN           NaN
# 114108                fr          NaN           NaN
# 98604                 ru          NaN           NaN
#
#                                      production_companies  \
# id
# 11224          RKO Radio Pictures|Walt Disney Productions
# 42884   Walt Disney Television|Citadel Entertainment|S...
# 92349                                                 NaN
# 105875                            GoodTimes Entertainment
# 261985  Beta Film|Lux Vide|ARD/Degeto Film GmbH|Rai Fi...
# 150689  Walt Disney Pictures|Genre Films|Beagle Pug Fi...
# 42651                                             Lenfilm
# 44459                                                 NaN
# 289673                                                NaN
# 114108                           Star-Film|Georges Méliès
# 98604              Channel One Russia|Central Partnership
#
#                            production_countries  ...  vote_average  \
# id                                               ...
# 11224                  United States of America  ...           6.8
# 42884                  United States of America  ...           6.1
# 92349                  United States of America  ...           5.4
# 105875           Japan|United States of America  ...           6.0
# 261985                                    Italy  ...           5.3
# 150689  United Kingdom|United States of America  ...           6.7
# 42651                                    Russia  ...           4.8
# 44459                  United States of America  ...           5.9
# 289673                                      NaN  ...           5.6
# 114108                                   France  ...           5.5
# 98604                                    Russia  ...           4.6
#
#         popularity  runtime  \
# id
# 11224    14.436858     74.0
# 42884     2.102013     88.0
# 92349     0.361288     52.0
# 105875    2.154873     48.0
# 261985    0.987462    180.0
# 150689   19.801128    105.0
# 42651     0.486073     80.0
# 44459     0.209552     77.0
# 289673    1.085134     90.0
# 114108    1.301063      5.0
# 98604     0.803588     91.0
#
#                                                  overview spoken_languages  \
# id
# 11224   Cinderella has faith her dreams of a better li...          English
# 42884   Updated version of the classic Rodgers and Ham...          English
# 92349   Based on Charles Perrault's fairy tale: Cinder...          English
# 105875  Cinderella, the beautiful and kind-hearted rag...        Afrikaans
# 261985  Once upon a time in post-war Rome: 13-year old...          English
# 150689  When her father unexpectedly passes away, youn...          English
# 42651   Based on a classic fairytale "Cinderella" bril...          Pусский
# 44459   The first of three TV-versions of the classic ...          English
# 289673  Cinderella (named Zezolla) and her family live...          English
# 114108  A fairy godmother magically turns Cinderella's...      No Language
# 98604   Masha Krapivina - is yet beautiful, and not th...          Pусский
#
#                                               poster_path  \
# id
# 11224   <img src='http://image.tmdb.org/t/p/w185//avz6...
# 42884   <img src='http://image.tmdb.org/t/p/w185//54aw...
# 92349   <img src='http://image.tmdb.org/t/p/w185//bL1K...
# 105875  <img src='http://image.tmdb.org/t/p/w185//rbzG...
# 261985  <img src='http://image.tmdb.org/t/p/w185//wjZK...
# 150689  <img src='http://image.tmdb.org/t/p/w185//iH4C...
# 42651   <img src='http://image.tmdb.org/t/p/w185//p41r...
# 44459   <img src='http://image.tmdb.org/t/p/w185//cB6I...
# 289673  <img src='http://image.tmdb.org/t/p/w185//gMYk...
# 114108  <img src='http://image.tmdb.org/t/p/w185//cf0g...
# 98604   <img src='http://image.tmdb.org/t/p/w185//nvGe...
#
#                                                      cast cast_size  \
# id
# 11224   Ilene Woods|Eleanor Audley|Lucille Bliss|Verna...        11
# 42884   Brandy Norwood|Whitney Houston|Whoopi Goldberg...         5
# 92349   Mary Pickford|Owen Moore|Isabel Vernon|Georgia...         7
# 105875  Tony Ail|Nathan Aswell|Chera Bailey|Kathleen B...         7
# 261985  Vanessa Hessler|Flavio Parenti|Natalia Wörner|...        14
# 150689  Lily James|Cate Blanchett|Richard Madden|Helen...        78
# 42651   Yanina Zhejmo|Aleksei Konsovsky|Faina Ranevska...         6
# 44459   Julie Andrews|Howard Lindsay|Howard Lindsay|Il...         9
# 289673  Kathleen Turner|Katrin Cartlidge|David Warner|...        10
# 114108  Georges Méliès|Barral|Bleuette Bernon|Carmely|...         6
# 98604   Kristina Asmus|Nikita Efremov|Artyom Tkachenko...        18
#
#         crew_size              director
# id
# 11224          50        Clyde Geronimi
# 42884           1         Robert Iscove
# 92349           2        James Kirkwood
# 105875          3      Toshiyuki Hiruma
# 261985         11      Christian Duguay
# 150689         80       Kenneth Branagh
# 42651           4  Nadezhda Kosheverova
# 44459          10          Ralph Nelson
# 289673          6         Beeban Kidron
# 114108          2        Georges Méliès
# 98604           4         Sergey Ivanov
#
# [11 rows x 21 columns]

# %%
df['genres'] = df.genres.astype(str)

# %%
from IPython.display import HTML

# %%
df_best = df[['poster_path','title','budget_musd','revenue_musd','vote_count','vote_average','popularity']]

# %%
df_best['Profit'] = df.revenue_musd.sub(df.budget_musd)
df_best['Return'] = df.revenue_musd.div(df.budget_musd)

# %%
df_best
# Out:
#                                               poster_path  \
# id
# 862     <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 8844    <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 15602   <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 31357   <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 11862   <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                   ...
# 439050  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 111109  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 67758   <img src='http://image.tmdb.org/t/p/w185//eGga...
# 227506  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 461257  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                               title  budget_musd  revenue_musd  vote_count  \
# id
# 862                       Toy Story         30.0    373.554033      5415.0
# 8844                        Jumanji         65.0    262.797249      2413.0
# 15602              Grumpier Old Men          NaN           NaN        92.0
# 31357             Waiting to Exhale         16.0     81.452156        34.0
# 11862   Father of the Bride Part II          NaN     76.578911       173.0
# ...                             ...          ...           ...         ...
# 439050                       Subdue          NaN           NaN         1.0
# 111109          Century of Birthing          NaN           NaN         3.0
# 67758                      Betrayal          NaN           NaN         6.0
# 227506             Satan Triumphant          NaN           NaN         0.0
# 461257                     Queerama          NaN           NaN         0.0
#
#         vote_average  popularity      Profit     Return
# id
# 862              7.7   21.946943  343.554033  12.451801
# 8844             6.9   17.015539  197.797249   4.043035
# 15602            6.5   11.712900         NaN        NaN
# 31357            6.1    3.859495   65.452156   5.090760
# 11862            5.7    8.387519         NaN        NaN
# ...              ...         ...         ...        ...
# 439050           4.0    0.072051         NaN        NaN
# 111109           9.0    0.178241         NaN        NaN
# 67758            3.8    0.903007         NaN        NaN
# 227506           NaN    0.003503         NaN        NaN
# 461257           NaN    0.163015         NaN        NaN
#
# [44691 rows x 9 columns]

# %% [markdown]
# ## Renaming Columns for visualization purpose

# %%
df_best.columns = ["",'Title','Budget','Revenue','Votes','Average Ratings','Popularity','Profit','ROI']

# %%
df_best
# Out:
#                                                            \
# id
# 862     <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 8844    <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 15602   <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 31357   <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 11862   <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                   ...
# 439050  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 111109  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 67758   <img src='http://image.tmdb.org/t/p/w185//eGga...
# 227506  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 461257  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                               Title  Budget     Revenue   Votes  \
# id
# 862                       Toy Story    30.0  373.554033  5415.0
# 8844                        Jumanji    65.0  262.797249  2413.0
# 15602              Grumpier Old Men     NaN         NaN    92.0
# 31357             Waiting to Exhale    16.0   81.452156    34.0
# 11862   Father of the Bride Part II     NaN   76.578911   173.0
# ...                             ...     ...         ...     ...
# 439050                       Subdue     NaN         NaN     1.0
# 111109          Century of Birthing     NaN         NaN     3.0
# 67758                      Betrayal     NaN         NaN     6.0
# 227506             Satan Triumphant     NaN         NaN     0.0
# 461257                     Queerama     NaN         NaN     0.0
#
#         Average Ratings  Popularity      Profit        ROI
# id
# 862                 7.7   21.946943  343.554033  12.451801
# 8844                6.9   17.015539  197.797249   4.043035
# 15602               6.5   11.712900         NaN        NaN
# 31357               6.1    3.859495   65.452156   5.090760
# 11862               5.7    8.387519         NaN        NaN
# ...                 ...         ...         ...        ...
# 439050              4.0    0.072051         NaN        NaN
# 111109              9.0    0.178241         NaN        NaN
# 67758               3.8    0.903007         NaN        NaN
# 227506              NaN    0.003503         NaN        NaN
# 461257              NaN    0.163015         NaN        NaN
#
# [44691 rows x 9 columns]

# %%
df_best.set_index('Title',inplace=True)

# %%
df_best
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                                        ...
# Subdue                       <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing          <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                     <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant             <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                     <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              Budget     Revenue   Votes  Average Ratings  \
# Title
# Toy Story                      30.0  373.554033  5415.0              7.7
# Jumanji                        65.0  262.797249  2413.0              6.9
# Grumpier Old Men                NaN         NaN    92.0              6.5
# Waiting to Exhale              16.0   81.452156    34.0              6.1
# Father of the Bride Part II     NaN   76.578911   173.0              5.7
# ...                             ...         ...     ...              ...
# Subdue                          NaN         NaN     1.0              4.0
# Century of Birthing             NaN         NaN     3.0              9.0
# Betrayal                        NaN         NaN     6.0              3.8
# Satan Triumphant                NaN         NaN     0.0              NaN
# Queerama                        NaN         NaN     0.0              NaN
#
#                              Popularity      Profit        ROI
# Title
# Toy Story                     21.946943  343.554033  12.451801
# Jumanji                       17.015539  197.797249   4.043035
# Grumpier Old Men              11.712900         NaN        NaN
# Waiting to Exhale              3.859495   65.452156   5.090760
# Father of the Bride Part II    8.387519         NaN        NaN
# ...                                 ...         ...        ...
# Subdue                         0.072051         NaN        NaN
# Century of Birthing            0.178241         NaN        NaN
# Betrayal                       0.903007         NaN        NaN
# Satan Triumphant               0.003503         NaN        NaN
# Queerama                       0.163015         NaN        NaN
#
# [44691 rows x 8 columns]

# %% [markdown]
# ### Visualizing posters of movies

# %%
subset = df_best.iloc[:5,:2]
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.0</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.0</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
#       <td>16.0</td>
#     </tr>
#     <tr>
#       <th>Father of the Bride Part II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_best.Votes.fillna(0,inplace=True)

# %%
# Function to get the desired movies titles based on its features
def best_worst(n,by,ascending=False,min_budget=0,min_votes=0):
    df_func = df_best.loc[(df_best.Budget>min_budget)&(df_best.Votes>min_votes),['',by]].sort_values(by=by,ascending=ascending).head(n).copy()
    return HTML(df_func.to_html(escape=False))

# %% [markdown]
# ## Top `5` highest rated  movies based on votes greater than `1000`

# %%
best_worst(n=5,min_votes=1000,by='Average Ratings')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Ratings</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Shawshank Redemption</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5KCVkau1HEl7ZzfPsKAPM0sMiKc.jpg' style='height:100px;'></td>
#       <td>8.5</td>
#     </tr>
#     <tr>
#       <th>The Godfather</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iVZ3JAcAjmguGPnRNfWFOtLHOuY.jpg' style='height:100px;'></td>
#       <td>8.5</td>
#     </tr>
#     <tr>
#       <th>Whiplash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tO6o2vnOh1ul2uGzzQOXZvtUhYZ.jpg' style='height:100px;'></td>
#       <td>8.3</td>
#     </tr>
#     <tr>
#       <th>Psycho</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//81d8oyEFgj7FlxJqSDXWr8JH8kV.jpg' style='height:100px;'></td>
#       <td>8.3</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>8.3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Top `5` highest grossing movies based on minimum budget of `$10` `million`

# %%
best_worst(n=5,min_budget=10,by="Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.965087</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.223624</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.034188</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>1519.557910</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rhr4y79GpxQF9IsfJItRXVaoGs4.jpg' style='height:100px;'></td>
#       <td>1513.528810</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Top `5` highest budget movies

# %%
best_worst(n=5,by="Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.0</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.0</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.0</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6ZYOpyhFZrAQIe1BuhqVgzfAdGZ.jpg' style='height:100px;'></td>
#       <td>270.0</td>
#     </tr>
#     <tr>
#       <th>John Carter</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7GSSyUUgUEXm1rhmiPGSRuKoqnK.jpg' style='height:100px;'></td>
#       <td>260.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Least `5` movies based on ROI

# %%
best_worst(n=5,ascending=True,by='ROI',min_budget=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Chasing Liberty</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7qzvS9QKkiDcz1K8EY9Y6ZXkUeD.jpg' style='height:100px;'></td>
#       <td>5.217391e-07</td>
#     </tr>
#     <tr>
#       <th>The Adventurer: The Curse of the Midas Box</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//31ykUoOS2RNdARk3B8z3y25gD8b.jpg' style='height:100px;'></td>
#       <td>2.559600e-04</td>
#     </tr>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>1.133938e-03</td>
#     </tr>
#     <tr>
#       <th>A Troll in Central Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bGSxFdoFg6vd0EDJPPoQ9lEtrq4.jpg' style='height:100px;'></td>
#       <td>3.102957e-03</td>
#     </tr>
#     <tr>
#       <th>1911</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//i5OV4nrsuMdQIt2OcJAz0aBZSb0.jpg' style='height:100px;'></td>
#       <td>3.611600e-03</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Top `5` most voted movies

# %%
best_worst(n=5,by='Votes',min_votes=2000)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.0</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.0</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.0</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>12000.0</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg' style='height:100px;'></td>
#       <td>11444.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Best `Harrison Ford` movies in `Action` genre

# %%
h_genre = df.genres.str.contains("Action")
h_cast = df.cast.str.contains("Harrison Ford")

display_result = df.loc[h_genre & h_cast,['title','poster_path','vote_average']].sort_values(by='vote_average',ascending=False).head(5)

HTML(display_result.to_html(escape=False,index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>The Empire Strikes Back</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//7BuH8itoSrLExs2YZSsM01Qk2no.jpg' style='height:100px;'></td>
#       <td>8.2</td>
#     </tr>
#     <tr>
#       <td>Star Wars</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'></td>
#       <td>8.1</td>
#     </tr>
#     <tr>
#       <td>Return of the Jedi</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//mDCBQNhR6R0PVFucJl0O4Hp5klZ.jpg' style='height:100px;'></td>
#       <td>7.9</td>
#     </tr>
#     <tr>
#       <td>Raiders of the Lost Ark</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//awUGN7ZCNq2EUTdpVaHDX23anOZ.jpg' style='height:100px;'></td>
#       <td>7.7</td>
#     </tr>
#     <tr>
#       <td>Indiana Jones and the Last Crusade</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sizg1AU8f8JDZX4QIgE4pjUMBvx.jpg' style='height:100px;'></td>
#       <td>7.6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Most successful `Warner Bros` movies between 2010 and 2017 (High Revenue)

# %% [markdown]
# Warner Bros.

# %%
company = df.production_companies.str.contains('Warner Bros.')
year_range = df.release_date.between('2015','2017')

warner = df.loc[company&year_range,['title','poster_path','revenue_musd','release_date']].sort_values(by='revenue_musd',ascending=False)

HTML(warner.to_html(escape=False,index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>title</th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Batman v Superman: Dawn of Justice</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//lQUFeo0oRvtiLKlT5zkQkuCW4jA.jpg' style='height:100px;'></td>
#       <td>873.260194</td>
#       <td>2016-03-23</td>
#     </tr>
#     <tr>
#       <td>Fantastic Beasts and Where to Find Them</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//h6NYfVUyM6CDURtZSnBpz647Ldd.jpg' style='height:100px;'></td>
#       <td>809.342332</td>
#       <td>2016-11-16</td>
#     </tr>
#     <tr>
#       <td>Suicide Squad</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//dwr75V4u87yGQwVLWUptnmFK0x8.jpg' style='height:100px;'></td>
#       <td>745.600054</td>
#       <td>2016-08-02</td>
#     </tr>
#     <tr>
#       <td>San Andreas</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//2Gfjn962aaFSD6eST6QU3oLDZTo.jpg' style='height:100px;'></td>
#       <td>470.490832</td>
#       <td>2015-05-27</td>
#     </tr>
#     <tr>
#       <td>Mad Max: Fury Road</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sQuxceRcV3cxKH5CAnAUZe0qFKS.jpg' style='height:100px;'></td>
#       <td>378.858340</td>
#       <td>2015-05-13</td>
#     </tr>
#     <tr>
#       <td>Sully</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//5L29r3uwDe49XDMaK2xDkDht9t0.jpg' style='height:100px;'></td>
#       <td>238.470033</td>
#       <td>2016-09-07</td>
#     </tr>
#     <tr>
#       <td>The Intern</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//j6XOiSHLgQ7VtgIhev30QEk15Tp.jpg' style='height:100px;'></td>
#       <td>194.564672</td>
#       <td>2015-09-24</td>
#     </tr>
#     <tr>
#       <td>Jupiter Ascending</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//mb4zAOosaO9tHyH1n7g0634moK0.jpg' style='height:100px;'></td>
#       <td>183.987723</td>
#       <td>2015-02-04</td>
#     </tr>
#     <tr>
#       <td>Storks</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//ylXKcKrEHSQEYLntBvYxGBI7Ld3.jpg' style='height:100px;'></td>
#       <td>182.379278</td>
#       <td>2016-09-22</td>
#     </tr>
#     <tr>
#       <td>Creed</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//1BfTsk5VWuw8FCocAhCyqnRbEzq.jpg' style='height:100px;'></td>
#       <td>173.567581</td>
#       <td>2015-11-25</td>
#     </tr>
#     <tr>
#       <td>The Accountant</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//oHMRhVytkVApLyCNML659LQZiQ1.jpg' style='height:100px;'></td>
#       <td>155.160045</td>
#       <td>2016-10-14</td>
#     </tr>
#     <tr>
#       <td>Pan</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//mYc7P87ZGpV9vZyX27LKIXPeMig.jpg' style='height:100px;'></td>
#       <td>128.388320</td>
#       <td>2015-09-24</td>
#     </tr>
#     <tr>
#       <td>Magic Mike XXL</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//uYJEfS90ZVh7yRIViXgucOYlMMr.jpg' style='height:100px;'></td>
#       <td>122.513057</td>
#       <td>2015-07-01</td>
#     </tr>
#     <tr>
#       <td>Get Hard</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//rJPbS2cYOYhDCjT5NmW1Fm6gFl3.jpg' style='height:100px;'></td>
#       <td>111.811453</td>
#       <td>2015-03-26</td>
#     </tr>
#     <tr>
#       <td>The Man from U.N.C.L.E.</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//9n8hkZXTdNsyMhW87jLuvDf7l4S.jpg' style='height:100px;'></td>
#       <td>108.145109</td>
#       <td>2015-08-13</td>
#     </tr>
#     <tr>
#       <td>In the Heart of the Sea</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//gLZEULfcS3uhfWDSEclOUgWiN41.jpg' style='height:100px;'></td>
#       <td>93.820758</td>
#       <td>2015-11-20</td>
#     </tr>
#     <tr>
#       <td>War Dogs</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//mDcPRjZC1bb6LavFU3gwsWdVfCM.jpg' style='height:100px;'></td>
#       <td>86.234523</td>
#       <td>2016-08-17</td>
#     </tr>
#     <tr>
#       <td>The Nice Guys</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//clq4So9spa9cXk3MZy2iMdqkxP2.jpg' style='height:100px;'></td>
#       <td>62.788218</td>
#       <td>2016-05-15</td>
#     </tr>
#     <tr>
#       <td>Hot Pursuit</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//qr84R3lL4uXFaBJqSlH90GEPvfz.jpg' style='height:100px;'></td>
#       <td>51.680201</td>
#       <td>2015-05-08</td>
#     </tr>
#     <tr>
#       <td>Entourage</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//y8zMue7ibjg7vXma6XE5tkQ3KiS.jpg' style='height:100px;'></td>
#       <td>49.263404</td>
#       <td>2015-06-03</td>
#     </tr>
#     <tr>
#       <td>Max</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//be3og74dUrZMl6QKNoHFOZ0ylPW.jpg' style='height:100px;'></td>
#       <td>43.967255</td>
#       <td>2015-06-26</td>
#     </tr>
#     <tr>
#       <td>Live by Night</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//bkd46T4RplawnDjpHoI8mhzTLks.jpg' style='height:100px;'></td>
#       <td>22.678555</td>
#       <td>2016-12-25</td>
#     </tr>
#     <tr>
#       <td>Midnight Special</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//heEe6NFekVHs23OKFtqhovyOMXQ.jpg' style='height:100px;'></td>
#       <td>6.212282</td>
#       <td>2016-02-18</td>
#     </tr>
#     <tr>
#       <td>Batman: The Killing Joke</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//wpfj8OdvHFTChA2WNHiEhBv24sk.jpg' style='height:100px;'></td>
#       <td>3.775000</td>
#       <td>2016-07-21</td>
#     </tr>
#     <tr>
#       <td>Justice League: Throne of Atlantis</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//wjD6lr6vi9DIwwyDZaOjGpIbulu.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-01-27</td>
#     </tr>
#     <tr>
#       <td>LEGO DC Comics Super Heroes: Justice League vs. Bizarro League</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//bp0exZFHBLV0gWNXkBINtymOeom.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-02-10</td>
#     </tr>
#     <tr>
#       <td>Batman vs. Robin</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//dBGUumJAdaNiJTFI6pkeHVVFwH8.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-04-14</td>
#     </tr>
#     <tr>
#       <td>Batman Unlimited: Animal Instincts</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//kxvw4c4Yx9HYqprP4lnZEtzezRd.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-05-12</td>
#     </tr>
#     <tr>
#       <td>The Flintstones & WWE: Stone Age Smackdown</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sEC1hwyG7pJaUazMtiroc31e3gK.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-03-17</td>
#     </tr>
#     <tr>
#       <td>Tom and Jerry Spy Quest</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sk6Kzkwp8vXPhluinKVQ4DrD2JC.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <td>Justice League: Gods and Monsters</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//bz9717vMiTw2EGvGQUPRK4WLQ6G.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-07-28</td>
#     </tr>
#     <tr>
#       <td>Scooby-Doo! And Kiss: Rock and Roll Mystery</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//nTkQZPXZl9yx3tfPS9TSDZBdhHC.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-07-10</td>
#     </tr>
#     <tr>
#       <td>Looney Tunes: Rabbits Run</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//7JekIelxRQtTaFbYqJSPr5Xw4KZ.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-08-04</td>
#     </tr>
#     <tr>
#       <td>Batman Unlimited: Monster Mayhem</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//uMkul1HN9zOWbbBzSYIaIKzhqdQ.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-08-18</td>
#     </tr>
#     <tr>
#       <td>Hidden</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//n4tv3GVt115IiZSV6sslEZe7fec.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#       <td>2015-09-15</td>
#     </tr>
#     <tr>
#       <td>LEGO DC Comics Super Heroes: Justice League: Attack of the Legion of Doom!</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//2KHaNPMncSX7b5FXKI5EoAJKw4R.j

# %% [markdown]
# ## Most used words in a title/tagline

# %%
# creating a single string containing all the titles
title_corpus = ''.join(df['title'])
# creating a single string containing all the tagline
tagline = df.tagline.dropna()
tagline_corpus = ''.join(tagline)

# %%
from wordcloud import WordCloud

titel_wordcloud = WordCloud(background_color='white',height=2000,width=4000,max_words=100).generate(title_corpus)

# %%
plt.figure(figsize=(16,8))
plt.imshow(titel_wordcloud,interpolation='bilinear')
plt.axis('off');

# %% [markdown]
# ## Franchise vs Stand Alone Movies

# %%
df['Franchise'] = df.belongs_to_collection.notna()

# %%
df.Franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %% [markdown]
# ### Average revenue

# %%
df.groupby('Franchise').revenue_musd.mean()
# Out:
# Franchise
# False     44.742814
# True     165.708193
# Name: revenue_musd, dtype: float64

# %% [markdown]
# ### ROI

# %%
df['ROI']= df.revenue_musd.div(df.budget_musd)

# median because there are ouliers
df.groupby("Franchise").ROI.median()
# Out:
# Franchise
# False    1.619699
# True     3.709195
# Name: ROI, dtype: float64

# %% [markdown]
# ### Average Budget

# %%
df.groupby('Franchise').budget_musd.mean()
# Out:
# Franchise
# False    18.047741
# True     38.319847
# Name: budget_musd, dtype: float64

# %%
df.groupby("Franchise").agg({
    'budget_musd':'mean',
    'revenue_musd':'mean',
    'ROI':'median',
    'popularity':'mean',
    'vote_count':'mean'
})
# Out:
#            budget_musd  revenue_musd       ROI  popularity  vote_count
# Franchise
# False        18.047741     44.742814  1.619699    2.592726   78.289550
# True         38.319847    165.708193  3.709195    6.245051  412.387856

# %% [markdown]
# ## Most successful franchises

# %%
franchises = df.groupby('belongs_to_collection').agg({
    'title':'count',
    'budget_musd':['sum','mean'],
    'revenue_musd':['sum','mean'],
    'ROI':'median',
    'popularity':'mean',
    'vote_count':'mean'
})

# %%
franchises
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2       130.0  65.0   366.780087
# 00 Schneider Filmreihe                   1         0.0   NaN     0.000000
# 08/15 Collection                         1         0.0   NaN     0.000000
# 100 Girls Collection                     2         0.0   NaN     0.000000
# 101 Dalmatians (Animated) Collection     2         4.0   4.0   215.880014
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1         0.0   NaN     0.000000
# Чебурашка и крокодил Гена                1         0.0   NaN     0.000000
# Что Творят мужчины! (Коллекция)          2         2.0   2.0     0.000000
# 男はつらいよ シリーズ                              3         0.0   NaN     0.000000
# 식객 시리즈                                   2         0.0   NaN     0.000000
#
#                                                         ROI popularity  \
#                                             mean     median       mean
# belongs_to_collection
# ... Has Fallen Collection             183.390043   2.864804  13.008090
# 00 Schneider Filmreihe                       NaN        NaN   1.931299
# 08/15 Collection                             NaN        NaN   0.628127
# 100 Girls Collection                         NaN        NaN   3.078652
# 101 Dalmatians (Animated) Collection  215.880014  53.970003  13.063212
# ...                                          ...        ...        ...
# Сказки Чуковского                            NaN        NaN   0.731334
# Чебурашка и крокодил Гена                    NaN        NaN   0.881504
# Что Творят мужчины! (Коллекция)              NaN        NaN   1.299605
# 男はつらいよ シリーズ                                  NaN        NaN   0.038901
# 식객 시리즈                                       NaN        NaN   0.157245
#
#                                        vote_count
#                                              mean
# belongs_to_collection
# ... Has Fallen Collection             2333.000000
# 00 Schneider Filmreihe                  16.000000
# 08/15 Collection                         4.000000
# 100 Girls Collection                    64.000000
# 101 Dalmatians (Animated) Collection   937.000000
# ...                                           ...
# Сказки Чуковского                        3.000000
# Чебурашка и крокодил Гена                7.000000
# Что Творят мужчины! (Коллекция)          5.500000
# 男はつらいよ シリーズ                              0.666667
# 식객 시리즈                                   3.500000
#
# [1691 rows x 8 columns]

# %%
franchises.nlargest(10,('ROI','median'))
# Out:
#                                           title budget_musd            \
#                                           count         sum      mean
# belongs_to_collection
# Blair Witch Collection                        3    5.060000  2.530000
# Super Size Me Collection                      1    0.065000  0.065000
# Open Water Collection                         2    1.330000  0.665000
# Bambi Collection                              2    0.858000  0.858000
# The Hills Have Eyes (Original) Collection     2    0.930000  0.465000
# Billy Jack Collection                         4    0.360007  0.180003
# Rocky Horror Collection                       2    1.200000  1.200000
# American Graffiti Collection                  2    3.277000  1.638500
# Cinderella Collection                         3   15.900000  5.300000
# Vixens Collection                             4    0.315000  0.157500
#
#                                           revenue_musd              \
#                                                    sum        mean
# belongs_to_collection
# Blair Witch Collection                      293.172994  146.586497
# Super Size Me Collection                     28.575078   28.575078
# Open Water Collection                        54.667954   54.667954
# Bambi Collection                            267.447150  267.447150
# The Hills Have Eyes (Original) Collection    25.000000   25.000000
# Billy Jack Collection                        36.000000   36.000000
# Rocky Horror Collection                     112.892319  112.892319
# American Graffiti Collection                155.014674   77.507337
# Cinderella Collection                       263.591415  263.591415
# Vixens Collection                             6.000000    6.000000
#
#                                                    ROI popularity  vote_count
#                                                 median       mean        mean
# belongs_to_collection
# Blair Witch Collection                     2071.183966  10.510581  632.000000
# Super Size Me Collection                    439.616585   5.266103  520.000000
# Open Water Collection                       420.522723  11.076564  238.500000
# Bambi Collection                            311.709965  10.744486  824.500000
# The Hills Have Eyes (Original) Collection   108.695652   3.941166   89.000000
# Billy Jack Collection                       100.000000   0.973566   10.500000
# Rocky Horror Collection                      94.076932   5.360314  360.000000
# American Graffiti Collection                 93.093025   6.136505  176.500000
# Cinderella Collection                        90.893591   9.800494  756.333333
# Vixens Collection                            78.947368   3.145358   27.000000

# %%
franchises.nlargest(10,('revenue_musd','sum'))
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# Harry Potter Collection                 8     1280.00  160.000000
# Star Wars Collection                    8      854.35  106.793750
# James Bond Collection                  26     1539.65   59.217308
# The Fast and the Furious Collection     8     1009.00  126.125000
# Pirates of the Caribbean Collection     5     1250.00  250.000000
# Transformers Collection                 5      965.00  193.000000
# Despicable Me Collection                6      299.00   74.750000
# The Twilight Collection                 5      385.00   77.000000
# Ice Age Collection                      5      429.00   85.800000
# Jurassic Park Collection                4      379.00   94.750000
#
#                                     revenue_musd                    ROI  \
#                                              sum        mean     median
# belongs_to_collection
# Harry Potter Collection              7707.367425  963.420928   6.165086
# Star Wars Collection                 7434.494790  929.311849   8.239637
# James Bond Collection                7106.970239  273.345009   6.128922
# The Fast and the Furious Collection  5125.098793  640.637349   4.942154
# Pirates of the Caribbean Collection  4521.576826  904.315365   3.453009
# Transformers Collection              4366.101244  873.220249   5.197167
# Despicable Me Collection             3691.070216  922.767554  12.761987
# The Twilight Collection              3342.107290  668.421458  10.271932
# Ice Age Collection                   3216.708553  643.341711   8.261760
# Jurassic Park Collection             3031.484143  757.871036   7.027789
#
#                                      popularity   vote_count
#                                            mean         mean
# belongs_to_collection
# Harry Potter Collection               26.253893  5983.250000
# Star Wars Collection                  23.410919  5430.375000
# James Bond Collection                 13.453502  1284.307692
# The Fast and the Furious Collection   10.799435  3197.000000
# Pirates of the Caribbean Collection   53.972237  5016.000000
# Transformers Collection               14.425077  3046.400000
# Despicable Me Collection             106.715961  3041.333333
# The Twilight Collection               29.500843  2770.200000
# Ice Age Collection                    16.075234  2643.800000
# Jurassic Park Collection              10.772810  4608.750000

# %% [markdown]
# ## Most Active Directors

# %%
df.director.value_counts().head(20)
# Out:
# John Ford             66
# Michael Curtiz        65
# Werner Herzog         54
# Alfred Hitchcock      53
# Georges Méliès        49
# Woody Allen           49
# Jean-Luc Godard       46
# Sidney Lumet          46
# Charlie Chaplin       44
# Raoul Walsh           43
# William A. Wellman    42
# Henry Hathaway        41
# Richard Thorpe        40
# Ingmar Bergman        39
# Martin Scorsese       39
# Fritz Lang            38
# John Huston           38
# George Cukor          38
# Mervyn LeRoy          37
# Robert Altman         37
# Name: director, dtype: int64

# %%
plt.figure(figsize=(15,8))
df.director.value_counts().head(20).plot(kind='bar',fontsize=15)
plt.title('Most Active Directors',fontsize=20)
plt.ylabel('No of flims',fontsize=20)
#plt.grid()
plt.show();

# %%
agg_directors = df.groupby('director').agg(Total_Revenue=('revenue_musd', 'sum'),
                                      Mean_Revenue=('revenue_musd', 'mean'),
                                      Mean_Rating=('vote_average', 'mean'),
                                      Mean_Pop=('popularity', 'mean'),
                                      Total_Movies=('director', 'count')
)

# %%
agg_directors
# Out:
#                      Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# director
#  Dale Trevillion\t        0.000000           NaN          4.0  0.041412
#  Davide Manuli            0.000000           NaN          6.9  1.031736
#  E.W. Swackhamer          0.000000           NaN          5.9  0.005351
#  Vitaliy Vorobyov         0.000000           NaN          5.5  0.479777
#  Yeon Sang-Ho             2.129768      2.129768          6.6  6.839452
# ...                            ...           ...          ...       ...
# Ярополк Лапшин            0.000000           NaN         10.0  0.000220
# پیمان معادی               0.000000           NaN          6.0  0.175791
# 塩谷 直義                     0.000000           NaN          7.2  4.299518
# 杰森·莫玛                     0.000000           NaN          5.8  3.764346
# 진모영                       0.000000           NaN          6.0  0.444564
#
#                      Total_Movies
# director
#  Dale Trevillion\t              2
#  Davide Manuli                  1
#  E.W. Swackhamer                1
#  Vitaliy Vorobyov               1
#  Yeon Sang-Ho                   4
# ...                           ...
# Ярополк Лапшин                  1
# پیمان معادی                     1
# 塩谷 直義                           1
# 杰森·莫玛                           1
# 진모영                             1
#
# [17349 rows x 5 columns]

# %%
agg_directors=agg_directors.sort_values(by='Total_Movies',ascending=False).reset_index(level=0)

# %%
plt.figure(figsize=(15,8))
plt.pie(x=agg_directors.Total_Movies.head(10),
        labels=agg_directors.director.head(10),autopct='%1.1f%%');

# %% [markdown]
# # Most Successful Directors

# %%
df.groupby('director').revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg     9256.621422
# Peter Jackson        6528.244659
# Michael Bay          6437.466781
# James Cameron        5900.610310
# David Yates          5334.563196
# Christopher Nolan    4747.408665
# Robert Zemeckis      4138.233542
# Tim Burton           4032.916124
# Ridley Scott         3917.529240
# Chris Columbus       3866.836869
# Roland Emmerich      3798.402596
# Ron Howard           3714.152341
# J.J. Abrams          3579.215315
# Gore Verbinski       3575.339236
# George Lucas         3341.550893
# Sam Raimi            3193.788606
# Francis Lawrence     3183.341910
# Clint Eastwood       3100.675162
# Bill Condon          3017.298095
# Joss Whedon          2963.831071
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize=(15,8))
df.groupby('director').revenue_musd.sum().nlargest(20).plot(kind='bar',fontsize=20)
plt.title("Most Successful Director",fontsize=25)
plt.ylabel('Revenue',fontsize=25);

# %% [markdown]
# # Actors

# %%
df.cast
# Out:
# id
# 862       Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 8844      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 15602     Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 31357     Whitney Houston|Angela Bassett|Loretta Devine|...
# 11862     Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                 ...
# 439050              Leila Hatami|Kourosh Tahami|Elham Korda
# 111109    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 67758     Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 227506    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 461257                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
act = df.cast.str.split('|',expand=True) #split the strings into lists and in seperate columns
act = act.stack().reset_index(level=1,drop=True).to_frame() # re-organize vertically
act.columns = ['Actor'] # assign column name
act
# Out:
#                     Actor
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
# merging the required columns in the newly created dataframe
act = act.merge(df[['title', 'revenue_musd', 'vote_average', 'popularity']],
                how='left', left_index=True, right_index=True
                )
act
# Out:
#                      Actor                            title  revenue_musd  \
# id
# 2              Turo Pajala                            Ariel           NaN
# 2         Susanna Haavisto                            Ariel           NaN
# 2          Matti Pellonpää                            Ariel           NaN
# 2             Eetu Hilkamo                            Ariel           NaN
# 3          Matti Pellonpää              Shadows in Paradise           NaN
# ...                    ...                              ...           ...
# 469172      Vasco Sequeira  Manuel on the Island of Wonders           NaN
# 469172     Armanda Bacelar  Manuel on the Island of Wonders           NaN
# 469172     Rafael de Sousa  Manuel on the Island of Wonders           NaN
# 469172  José Antônio Gomes  Manuel on the Island of Wonders           NaN
# 469172       Isabel Branco  Manuel on the Island of Wonders           NaN
#
#         vote_average  popularity
# id
# 2                7.1    3.860491
# 2                7.1    3.860491
# 2                7.1    3.860491
# 2                7.1    3.860491
# 3                7.1    2.292110
# ...              ...         ...
# 469172           NaN    0.001097
# 469172           NaN    0.001097
# 469172           NaN    0.001097
# 469172           NaN    0.001097
# 469172           NaN    0.001097
#
# [557703 rows x 5 columns]

# %%
act.Actor.nunique()
# Out:
# 201501

# %%
act.Actor.unique()
# Out:
# array(['Turo Pajala', 'Susanna Haavisto', 'Matti Pellonpää', ...,
#        'Armanda Bacelar', 'Rafael de Sousa', 'José Antônio Gomes'],
#       dtype=object)

# %% [markdown]
# # Most Active Actor

# %%
plt.figure(figsize=(15,8))
act.Actor.value_counts().head(10).plot(kind='bar',fontsize=20)
plt.title("Most Active Actor",fontsize=20)
#plt.grid()
plt.yticks(np.arange(0,250,20))
plt.ylabel('No of Movies',fontsize=20);

# %%
agg_actors = act.groupby('Actor').agg(Total_Revenue=('revenue_musd', 'sum'),
                                      Mean_Revenue=('revenue_musd', 'mean'),
                                      Mean_Rating=('vote_average', 'mean'),
                                      Mean_Pop=('popularity', 'mean'),
                                      Total_Movies=('Actor', 'count'),
                                      )

# %% [markdown]
# ## Most Profitable Actor

# %%
top_ten_profitable_actors = agg_actors.nlargest(10,'Total_Revenue').reset_index(level=0)

# %%
top_ten_profitable_actors
# Out:
#                Actor  Total_Revenue  Mean_Revenue  Mean_Rating   Mean_Pop  \
# 0           Stan Lee   19414.957555    647.165252     6.513043  29.936175
# 1  Samuel L. Jackson   17109.620672    213.870258     6.266116  11.703945
# 2      Warwick Davis   13256.032188    662.801609     6.294118  13.088614
# 3       Frank Welker   13044.152470    326.103812     6.310377   9.571404
# 4  John Ratzenberger   12596.126073    449.861645     6.484444  10.959477
# 5       Jess Harnell   12234.608163    611.730408     6.435294  10.919015
# 6       Hugo Weaving   11027.578473    459.482436     6.473684  10.967890
# 7       Ian McKellen   11015.592318    478.938796     6.353488  15.447180
# 8        Johnny Depp   10653.760641    217.423687     6.440580  12.378196
# 9       Alan Rickman   10612.625348    353.754178     6.715556  10.399285
#
#    Total_Movies
# 0            48
# 1           122
# 2            34
# 3           107
# 4            46
# 5            35
# 6            40
# 7            44
# 8            69
# 9            45

# %%
most_profitable = agg_actors.Total_Revenue.sort_values(ascending=False)
y_value = top_ten_profitable_actors.Total_Revenue.nlargest(10)
plt.figure(figsize=(15,7))
sns.barplot(x=top_ten_profitable_actors.Actor,y=y_value)
plt.yticks(fontsize=20)
plt.title("Most Profitable Actors",fontsize=20)
plt.ylabel('Total Revenue in millions',fontsize=20)
plt.xlabel('Actors',fontsize=20)
#plt.grid()
plt.xticks(rotation=90,fontsize=20);

# %% [markdown]
# ## Top 10 countries releasing movies

# %%
df.production_countries.dropna(inplace=True)

# %%
country = df.production_countries.str.split('|',expand=True)
country = country.stack().reset_index(level=1,drop=True)
country = country.to_frame()
country.columns = ['Countries']
country
# Out:
#                        Countries
# id
# 862     United States of America
# 8844    United States of America
# 15602   United States of America
# 31357   United States of America
# 11862   United States of America
# ...                          ...
# 439050                      Iran
# 111109               Philippines
# 67758   United States of America
# 227506                    Russia
# 461257            United Kingdom
#
# [48986 rows x 1 columns]

# %%
countries = country.merge(df[
    'title'], how='left', left_index=True, right_index=True)
countries = countries.groupby('Countries').agg(
    Total_movies=('Countries', 'count')
)
countries = countries.reset_index(level=0)
countries = countries.sort_values(by='Total_movies', ascending=False)
countries['Countries'] = countries['Countries'].replace(
    ['United States of America'], 'USA')

# %%
x_data = countries.Countries.head(10)
y_data = countries.Total_movies.head(10)
plt.figure(figsize=(15,7))
sns.barplot(x=x_data,y=y_data)
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=15)
plt.xlabel('Countries',fontsize=20)
plt.ylabel('Total No of Movies',fontsize=20)
plt.title('Top 10 Countries Releasing Movies',fontsize=25);

# %% [markdown]
# The end
